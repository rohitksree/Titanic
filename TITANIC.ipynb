# %% [markdown]
# ## Supressing the warning messages

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import some Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic = pd.read_csv('train.csv')

# %% [markdown]
# ## Check the Details of Data

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
titanic.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# ## Creating Bar chart as the Target variable is Categorical

# %%
GroupedData=titanic.groupby('Survived').size()
GroupedData.plot(kind='bar', figsize=(4,3))
# Out:
# <AxesSubplot:xlabel='Survived'>

# %% [markdown]
# ### Looking at the descriptive statistics of the data

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                       Name   Sex  \
# count    891.000000  891.000000  891.000000                        891   891
# unique          NaN         NaN         NaN                        891     2
# top             NaN         NaN         NaN  Sivola, Mr. Antti Wilhelm  male
# freq            NaN         NaN         NaN                          1   577
# mean     446.000000    0.383838    2.308642                        NaN   NaN
# std      257.353842    0.486592    0.836071                        NaN   NaN
# min        1.000000    0.000000    1.000000                        NaN   NaN
# 25%      223.500000    0.000000    2.000000                        NaN   NaN
# 50%      446.000000    0.000000    3.000000                        NaN   NaN
# 75%      668.500000    1.000000    3.000000                        NaN   NaN
# max      891.000000    1.000000    3.000000                        NaN   NaN
#
# ...

# %% [markdown]
# ## Removing useless columns from the data

# %%
# Deleting those columns which are not useful in predictive analysis because these variables are qualitative
UselessColumns = ['PassengerId','Name','Ticket','Cabin']
titanic = titanic.drop(UselessColumns,axis=1)
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ## Visual Exploratory Data Analysis
#
# Plotting multiple bar charts at once for categorical variables
#
# Since there is no default function which can plot bar charts for multiple columns at once
#
# Defining our own function for the same

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(20,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
# Calling the function
PlotBarCharts(inpData=titanic, colsToPlot=['Pclass', 'Sex', 'SibSp','Parch','Embarked'])

# %% [markdown]
# ### Based on the Basic Data Exploration, there are two continuous predictor variables 'Age',and 'Fare'

# %%
# Plotting histograms of multiple columns together
# Observe that ApplicantIncome and CoapplicantIncome has outliers
titanic.hist(['Age', 'Fare'], figsize=(18,5))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fare'}>]], dtype=object)

# %%
sns.boxplot(titanic['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# ### Selected Continuous Variables:
#
# -> Age : Selected. The distribution is good.
#
# -> Fare: Selected. Outliers seen beyond 300, need to treat them.

# %% [markdown]
# ## Outlier treatment

# %% [markdown]
# ### Replacing outliers for 'Fare'

# %%
# Finding nearest values to 300 mark
titanic['Fare'][titanic['Fare']<300].sort_values(ascending=False)
# Out:
# 341    263.000
# 438    263.000
# 27     263.000
# 88     263.000
# 311    262.375
#         ...
# 277      0.000
# 633      0.000
# 302      0.000
# 597      0.000
# 271      0.000
# Name: Fare, Length: 888, dtype: float64

# %%
# Replacing outliers with nearest possibe value
titanic['Fare'][titanic['Fare']>300] = 263.0

# %% [markdown]
# ## Visualizing distribution after outlier treatment

# %%
titanic.hist(['Age','Fare'], figsize=(18,5))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fare'}>]], dtype=object)

# %%
sns.boxplot(titanic['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# ## Missing values treatment

# %%
# Finding how many missing values are there for each column
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
# Replacing missing values of Age with median value
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)

# %%
# Replacing missing values of Age with median value
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)

# %%
# Replacing missing values of Embarked with Mode value
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# %%
# Checking of Embarked after replacing the missing value 
titanic.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ## Relationship exploration: Categorical Vs Continuous -- Box Plots

# %%
# Box plots for Categorical Target Variable "Survived" and continuous predictors
ContinuousColsList=['Age','Fare']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=1, ncols=len(ContinuousColsList), figsize=(18,5))

# Creating box plots for each continuous predictor against the Target Variable "Survived"
for PredictorCol , i in zip(ContinuousColsList, range(len(ContinuousColsList))):
    titanic.boxplot(column=PredictorCol, by='Survived', figsize=(5,5), vert=True, ax=PlotCanvas[i])

# %% [markdown]
# ## Statistical Feature Selection (Categorical Vs Continuous) using ANOVA test

# %%
## Statistical Feature Selection (Categorical Vs Continuous) using ANOVA test# Defining a function to find the statistical relationship with all the categorical variables
def FunctionAnova(inpData, TargetVariable, ContinuousPredictorList):
    from scipy.stats import f_oneway

    # Creating an empty list of final selected predictors
    SelectedPredictors=[]
    
    print('##### ANOVA Results ##### \n')
    for predictor in ContinuousPredictorList:
        CategoryGroupLists=inpData.groupby(TargetVariable)[predictor].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        
        # If the ANOVA P-Value is <0.05, that means we reject H0
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
    
    return(SelectedPredictors)

# %%
# Calling the function to check which categorical variables are correlated with target
ContinuousVariables=['Age','Fare']
FunctionAnova(inpData=titanic, TargetVariable='Survived', ContinuousPredictorList=ContinuousVariables)
# Out:
# ##### ANOVA Results #####
#
# Age is NOT correlated with Survived | P-Value: 0.052760688475835
# Fare is correlated with Survived | P-Value: 1.8421954983111479e-16
# ['Fare']

# %% [markdown]
# ### According to Anova test, p-value of 'Age' is H0 by a little margin

# %% [markdown]
# ## Relationship exploration: Categorical Vs Categorical -- Grouped Bar Charts

# %%
# Cross tablulation between two categorical variables
CrossTabResult=pd.crosstab(index=titanic['Sex'], columns=titanic['Survived'])
CrossTabResult
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
# Visual Inference using Grouped Bar charts
CategoricalColsList=['Pclass', 'Sex', 'SibSp','Parch','Embarked']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=len(CategoricalColsList), ncols=1, figsize=(10,30))

# Creating Grouped bar plots for each categorical predictor against the Target Variable "Survived"
for CategoricalCol , i in zip(CategoricalColsList, range(len(CategoricalColsList))):
    CrossTabResult=pd.crosstab(index=titanic[CategoricalCol], columns=titanic['Survived'])
    CrossTabResult.plot.bar(color=['blue','green'], ax=PlotCanvas[i], title=CategoricalCol+' Vs '+'Survived')

# %% [markdown]
# ## Chi-Square test
# Chi-Square test is conducted to check the correlation between two categorical variables

# %%
# Writing a function to find the correlation of all categorical variables with the Target variable
def FunctionChisq(inpData, TargetVariable, CategoricalVariablesList):
    from scipy.stats import chi2_contingency
    
    # Creating an empty list of final selected predictors
    SelectedPredictors=[]

    for predictor in CategoricalVariablesList:
        CrossTabResult=pd.crosstab(index=inpData[TargetVariable], columns=inpData[predictor])
        ChiSqResult = chi2_contingency(CrossTabResult)
        
        # If the ChiSq P-Value is <0.05, that means we reject H0
        if (ChiSqResult[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', ChiSqResult[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', ChiSqResult[1])        
            
    return(SelectedPredictors)

# %%
CategoricalVariables=['Pclass', 'Sex', 'SibSp','Parch','Embarked']

# Calling the function
FunctionChisq(inpData=titanic, 
              TargetVariable='Survived',
              CategoricalVariablesList= CategoricalVariables)
# Out:
# Pclass is correlated with Survived | P-Value: 4.549251711298793e-23
# Sex is correlated with Survived | P-Value: 1.1973570627755645e-58
# SibSp is correlated with Survived | P-Value: 1.5585810465902116e-06
# Parch is correlated with Survived | P-Value: 9.703526421039997e-05
# Embarked is correlated with Survived | P-Value: 2.3008626481449577e-06
# ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']

# %%
SelectedColumns=['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked','Fare']

# Selecting final columns
sel_col=titanic[SelectedColumns]
sel_col.head(8)
# Out:
#    Pclass     Sex  SibSp  Parch Embarked     Fare
# 0       3    male      1      0        S   7.2500
# 1       1  female      1      0        C  71.2833
# 2       3  female      0      0        S   7.9250
# 3       1  female      1      0        S  53.1000
# 4       3    male      0      0        S   8.0500
# 5       3    male      0      0        Q   8.4583
# 6       1    male      0      0        S  51.8625
# 7       3    male      3      1        S  21.0750

# %% [markdown]
# ## Converting Character into Numeric

# %%
# Converting the binary nominal variable sex to numeric
sel_col['Sex'].replace({'female':0, 'male':1}, inplace=True)

# %% [markdown]
# ### Converting the nominal variable to numeric using get_dummies

# %%
# Treating all the nominal variables at once using dummy variables
sel_col_Numeric=pd.get_dummies(sel_col)

# Adding Target Variable to the data
sel_col_Numeric['Survived']=titanic['Survived']

# Printing sample rows
sel_col_Numeric.head(8)
# Out:
#    Pclass  Sex  SibSp  Parch     Fare  Embarked_C  Embarked_Q  Embarked_S  \
# 0       3    1      1      0   7.2500           0           0           1
# 1       1    0      1      0  71.2833           1           0           0
# 2       3    0      0      0   7.9250           0           0           1
# 3       1    0      1      0  53.1000           0           0           1
# 4       3    1      0      0   8.0500           0           0           1
# 5       3    1      0      0   8.4583           0           1           0
# 6       1    1      0      0  51.8625           0           0           1
# 7       3    1      3      1  21.0750           0           0           1
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
# 5         0
# 6         0
# 7         0

# %%
sel_col_Numeric.columns
# Out:
# Index(['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked_C', 'Embarked_Q',
#        'Embarked_S', 'Survived'],
#       dtype='object')

# %% [markdown]
# ### Separate Target Variable and Predictor Variables

# %%
TargetVariable='Survived'
Predictors=['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked_C', 'Embarked_Q','Embarked_S']

# %% [markdown]
# ## Split the data into X and Y

# %%
X=sel_col_Numeric[Predictors].values
Y=sel_col_Numeric[TargetVariable].values

# %%
X.shape, Y.shape
# Out:
# ((891, 8), (891,))

# %% [markdown]
# ## Split the data into training and testing Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((623, 8), (268, 8), (623,), (268,))

# %%
X_train.sum()
# Out:
# 1608.6226054499366

# %% [markdown]
# ## Perform the Data through different Machine Learning
# 1). Logistic Regression
#
# 2). Decision Tree
#
# 3). Random Forest
#
# 4). KNN
#
# 5). Naive Bayes

# %% [markdown]
# ## 1.Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
# choose parameter Penalty='l1' or C=1
# choose different values for solver 'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'
model = LogisticRegression(C=5,penalty='l2', solver='newton-cg')

# %%
# Printing all the parameters of logistic regression
print(model)
# Out:
# LogisticRegression(C=5, solver='newton-cg')

# %% [markdown]
# #### Creating the model on Training Data

# %%
LOG=model.fit(X_train,Y_train)
prediction=LOG.predict(X_test)

# %% [markdown]
# #### Measuring accuracy on Testing Data

# %%
from sklearn import metrics
print(metrics.classification_report(Y_test, prediction))
print(metrics.confusion_matrix(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       157
#            1       0.73      0.73      0.73       111
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.77      0.77       268
# weighted avg       0.78      0.78      0.78       268
#
# [[127  30]
#  [ 30  81]]

# %%
# Printing the Overall Accuracy of the model
F1_Score=metrics.f1_score(Y_test, prediction, average='weighted')
print('Accuracy of the model on Testing Sample Data:', round(F1_Score,2))
# Out:
# Accuracy of the model on Testing Sample Data: 0.78

# %% [markdown]
# ## Cross Validation

# %%
# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# %%
# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(LOG, X , Y, cv=10, scoring='f1_weighted')
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),3))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [0.77649393 0.77641044 0.77021909 0.82182649 0.7987694  0.75981111
#  0.78268624 0.75756502 0.79649424 0.78302904]
#
# Final Average Accuracy of the model: 0.782

# %% [markdown]
# # Statement:-

# %% [markdown]
# ## In Logistic Regression The Model's Performance Accuracy is 78.2%

# %% [markdown]
# ## 2.Decision Trees

# %%
#Decision Trees
from sklearn import tree
#choose from different tunable hyper parameters
model = tree.DecisionTreeClassifier(max_depth=3,criterion='entropy')

# %%
# Printing all the parameters of Decision Trees
print(model)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %% [markdown]
# #### Creating the model on Training Data

# %%
DTree=model.fit(X_train,Y_train)
prediction=DTree.predict(X_test)

# %% [markdown]
# #### Measuring accuracy on Testing Data

# %%
from sklearn import metrics
print(metrics.classification_report(Y_test, prediction))
print(metrics.confusion_matrix(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       157
#            1       0.83      0.68      0.75       111
#
#     accuracy                           0.81       268
#    macro avg       0.81      0.79      0.80       268
# weighted avg       0.81      0.81      0.81       268
#
# [[141  16]
#  [ 35  76]]

# %%
# Printing the Overall Accuracy of the model
F1_Score=metrics.f1_score(Y_test, prediction, average='weighted')
print('Accuracy of the model on Testing Sample Data:', round(F1_Score,2))
# Out:
# Accuracy of the model on Testing Sample Data: 0.81

# %%
# Plotting the feature importance for Top 10 most important columns
feature_importances = pd.Series(DTree.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Cross Validation

# %%
# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(DTree, X , Y, cv=10, scoring='f1_weighted')
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),3))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [0.80938963 0.81776069 0.76791722 0.83190886 0.82022472 0.78065407
#  0.7911255  0.77562138 0.82683216 0.79359477]
#
# Final Average Accuracy of the model: 0.802

# %% [markdown]
# ### Plotting a Decision Tree

# %%
from dtreeplt import dtreeplt
dtree = dtreeplt(model=model, feature_names=Predictors, target_names=TargetVariable)
fig = dtree.view()
currentFigure=plt.gcf()
currentFigure.set_size_inches(30,10)

# %% [markdown]
# # Statement:-

# %% [markdown]
# ## In Decision Tree The Model's Performance Accuracy is 80.2%

# %% [markdown]
# ## 3.Random Forest

# %%
# Random Forest (Bagging of multiple Decision Trees)
from sklearn.ensemble import RandomForestClassifier
# Choose different hyperparameter values of max_depth, n_estimators and criterion to tune the model
model = RandomForestClassifier(max_depth=4, n_estimators=200,criterion='gini')

# %%
# Printing all the parameters of Random Forest
print(model)
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=200)

# %% [markdown]
# #### Creating the model on Training Data

# %%
RF=model.fit(X_train,Y_train)
prediction=RF.predict(X_test)

# %%
# Measuring accuracy on Testing Data
from sklearn import metrics
print(metrics.classification_report(Y_test, prediction))
print(metrics.confusion_matrix(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83       157
#            1       0.81      0.64      0.71       111
#
#     accuracy                           0.79       268
#    macro avg       0.79      0.77      0.77       268
# weighted avg       0.79      0.79      0.78       268
#
# [[140  17]
#  [ 40  71]]

# %%
# Printing the Overall Accuracy of the model
F1_Score=metrics.f1_score(Y_test, prediction, average='weighted')
print('Accuracy of the model on Testing Sample Data:', round(F1_Score,2))
# Out:
# Accuracy of the model on Testing Sample Data: 0.78

# %%
# Plotting the feature importance for Top 10 most important columns

feature_importances = pd.Series(RF.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Cross Validation

# %%
# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RF, X , Y, cv=10, scoring='f1_weighted')
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),3))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [0.77310824 0.747241   0.77562138 0.85350049 0.85250075 0.81433378
#  0.81433378 0.72838378 0.81221749 0.81286104]
#
# Final Average Accuracy of the model: 0.798

# %%
# PLotting a single Decision Tree from Random Forest
from dtreeplt import dtreeplt
dtree = dtreeplt(model=model.estimators_[4], feature_names=Predictors, target_names=TargetVariable)
fig = dtree.view()
currentFigure=plt.gcf()
currentFigure.set_size_inches(50,20)

# %% [markdown]
# # Statement:-

# %% [markdown]
# ## In Random Forest The Model's Performance Accuracy is 79.4%

# %% [markdown]
# ## Standardization/Normalization of data
# we can choose not to run this step if we want to compare the resultant accuracy of this transformation with the accuracy of raw data.
#
# However, if we are using KNN, then this step becomes necessary.

# %%
### Sandardization of data ###
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Choose either standardization or Normalization
# On this data Min Max Normalization produced better results

# Choose between standardization and MinMAx normalization
#PredictorScaler=StandardScaler()
PredictorScaler=MinMaxScaler()

# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(X)

# Generating the standardized values of X
X=PredictorScalerFit.transform(X)

# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# ## 4.KNN- K-Nearest Neighbor

# %%
# K-Nearest Neighbor(KNN)
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=4)

# %%
# Printing all the parameters of KNN
print(model)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %% [markdown]
# #### Creating the model on Training Data

# %%
KNN=model.fit(X_train,Y_train)
prediction=KNN.predict(X_test)

# %%
# Measuring accuracy on Testing Data
from sklearn import metrics
print(metrics.classification_report(Y_test, prediction))
print(metrics.confusion_matrix(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       157
#            1       0.82      0.63      0.71       111
#
#     accuracy                           0.79       268
#    macro avg       0.80      0.77      0.77       268
# weighted avg       0.80      0.79      0.79       268
#
# [[142  15]
#  [ 41  70]]

# %%
# Printing the Overall Accuracy of the model
F1_Score=metrics.f1_score(Y_test, prediction, average='weighted')
print('Accuracy of the model on Testing Sample Data:', round(F1_Score,2))
# Out:
# Accuracy of the model on Testing Sample Data: 0.79

# %% [markdown]
# ## Cross Validation

# %%
# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score
# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(KNN, X , Y, cv=10, scoring='f1_weighted')
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),3))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [0.73525585 0.73848117 0.70074823 0.83321973 0.88395861 0.75981111
#  0.80164322 0.73163495 0.8284365  0.82353901]
#
# Final Average Accuracy of the model: 0.784

# %% [markdown]
# # Statement:-

# %% [markdown]
# ## In KNN The Model's Performance Accuracy is 78.4%

# %% [markdown]
# ## 5.Naive Bayes

# %%
# Naive Bays
from sklearn.naive_bayes import GaussianNB

# %%
# GaussianNB is used in Binomial Classification
model = GaussianNB()

# %%
# Printing all the parameters of Naive Bayes
print(model)
# Out:
# GaussianNB()

# %% [markdown]
# #### Creating the model on training data

# %%
NB=model.fit(X_train,Y_train)
prediction=NB.predict(X_test)

# %%
# Measuring accuracy on Testing Data
from sklearn import metrics
print(metrics.classification_report(Y_test, prediction))
print(metrics.confusion_matrix(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.74      0.79       157
#            1       0.68      0.80      0.74       111
#
#     accuracy                           0.76       268
#    macro avg       0.76      0.77      0.76       268
# weighted avg       0.78      0.76      0.77       268
#
# [[116  41]
#  [ 22  89]]

# %%
# Printing the Overall Accuracy of the model
F1_Score=metrics.f1_score(Y_test, prediction, average='weighted')
print('Accuracy of the model on Testing Sample Data:', round(F1_Score,2))
# Out:
# Accuracy of the model on Testing Sample Data: 0.77

# %% [markdown]
# ## Cross Validation

# %%
# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(NB, X , Y, cv=10, scoring='f1_weighted')
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),3))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [0.75555556 0.73349062 0.76173197 0.76732168 0.78874499 0.7752809
#  0.80842372 0.79775281 0.78442417 0.82022472]
#
# Final Average Accuracy of the model: 0.779

# %% [markdown]
# # Statement:-

# %% [markdown]
# ## In Naive Bayes The Model's Performance Accuracy is 77.9%

# %% [markdown]
# # FINAL STATEMENT:-

# %% [markdown]
# # Model's Accurancy in
# 1. Logistic Regression is 78.2%
#
# 2. Decision Tree is 80.2%
#
# 3. Random Forest is 79.4%
#
# 4. KNN is 78.4%
#
# 5. Naive Bayes is 77.9%

# %% [markdown]
# # I Choose Decision Tree on the basis of above performances of the Model, Decision Tree give more accuracte than the other Algorithms

# %% [markdown]
# # Prediction :-

# %% [markdown]
# ## On the Basis of Model's performance in Decision Tree I can predict the 80.2% of Survive on the Ship who board

# %% [markdown]
# # Predict By:- ROHIT KUMAR
# Programme:- BUSINESS ANALYTICS
